# %%
# !pip install google_play_scraper
from google_play_scraper import Sort, reviews
import pandas as pd
# Out:
# Collecting google_play_scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 3.5 MB/s eta 0:00:00
# Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google_play_scraper
# Successfully installed google_play_scraper-1.2.7

# %%
review, continuation_token = reviews(
    'id.dana', #ID aplikasi
    lang = 'id', #defaults to 'en'
    country = 'id', #defaults to 'us'
    sort = Sort.MOST_RELEVANT, #defaults to Sort.MOST_RELEVANT
    count = 300, #defaults to 50
)

# %%
app_reviews_df = pd.DataFrame(review)

# %%
app_reviews_df.head()
# Out:
#                                reviewId            userName  \
# 0  765d2124-4c1c-4460-a60e-a2369072cf69       Agie Grenaldy
# 1  0181cba3-2601-4271-9c66-38412e4752e9      artantia wulan
# 2  59208e0c-774c-42ce-b940-5ecc7c486df5  Noviana Pujiansyah
# 3  a7571644-8f7b-4500-ad33-0f73b779cd4a     Sartika Nuryani
# 4  8f54dc69-d1e2-4d77-b0a6-1f9792fe190b       rofi .hachola
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2  https://play-lh.googleusercontent.com/a-/ALV-U...
# 3  https://play-lh.googleusercontent.com/a/ACg8oc...
# 4  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                              content  score  thumbsUpCount  \
# 0  Tolong bantuannya, saya tidak bisa cek riwayat...      2            504
# 1  Yang mau instal apk ini mending mikir" lagi, a...      1            165
# 2  suka bangettt sama aplikasi ini memudahkan pen...      5           1409
# 3  Kenapa menggunakan data seluler pribadi pasti ...      4           1477
# 4  gak jelasssss, dulu pakai data seluler bisa tr...      1             15
#
#   reviewCreatedVersion                  at  \
# 0               2.69.0 2024-11-28 00:12:02
# 1               2.69.1 2024-12-10 09:51:25
# 2               2.69.0 2024-12-04 21:49:47
# 3               2.69.1 2024-12-07 14:51:57
# 4               2.70.0 2024-12-14 07:13:46
#
#                                         replyContent           repliedAt  \
# 0                                               None                 NaT
# 1                                               None                 NaT
# 2  Hi Kak, terima kasih ya sudah mempercayakan DA... 2022-12-06 04:06:45
# 3                                               None                 NaT
# 4                                               None                 NaT
#
#   appVersion
# 0     2.69.0
# 1     2.69.1
# 2     2.69.0
# 3     2.69.1
# 4     2.70.0

# %%
app_reviews_df.to_csv('dana-review-playstore.csv', index=False)
